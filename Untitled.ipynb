# %%
import pandas as pd

# %%
df = pd.read_csv("datatran2019.csv", sep=';', error_bad_lines=False, encoding = 'cp1252')

# %%
df.head(10)
# Out:
#          id data_inversa   dia_semana   horario  uf     br     km  \
# 0  182210.0   2019-01-01  terça-feira  01:30:00  SP  116.0    218
# 1  182211.0   2019-01-01  terça-feira  01:30:00  PR  373.0  177,3
# 2  182212.0   2019-01-01  terça-feira  00:45:00  SC  101.0     16
# 3  182214.0   2019-01-01  terça-feira  00:00:00  CE   20.0  429,5
# 4  182215.0   2019-01-01  terça-feira  01:00:00  MG  381.0    327
# 5  182216.0   2019-01-01  terça-feira  01:50:00  SC  470.0   42,6
# 6  182217.0   2019-01-01  terça-feira  01:30:00  MS  163.0  721,5
# 7  182219.0   2019-01-01  terça-feira  00:50:00  GO   50.0  280,3
# 8  182220.0   2019-01-01  terça-feira  02:25:00  GO   60.0    172
# 9  182223.0   2019-01-01  terça-feira  02:15:00  RS  386.0   73,7
#
#                municipio                                     causa_acidente  \
# 0              GUARULHOS                        Falta de Atenção à Condução
# 1           PONTA GROSSA                        Falta de Atenção à Condução
# ...

# %%
import csv

# %%
with open('datatran2019.csv') as f:
   print(f)
# Out:
# <_io.TextIOWrapper name='datatran2019.csv' mode='r' encoding='UTF-8'>
